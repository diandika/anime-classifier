# %%
import math
import pandas as pd
import requests

# %%
df = pd.read_csv("data_file/AnimeList.csv", sep=',')
df = df[df['image_url'].notna()]
df.head(125)
# Out:
#      anime_id                               title  \
# 0       11013                       Inu x Boku SS
# 1        2104                    Seto no Hanayome
# 2        5262                  Shugo Chara!! Doki
# 3         721                       Princess Tutu
# 4       12365                 Bakuman. 3rd Season
# ..        ...                                 ...
# 120     18893   Aoki Hagane no Arpeggio: Ars Nova
# 121     35334             ClassicaLoid 2nd Season
# 122     36755  Juvenile Pornography The Animation
# 123      3164      Ichigo Ichie: Koibana Tomobana
# 125      2199                      Chirin no Suzu
#
#                          title_english                title_japanese  \
# 0            Inu X Boku Secret Service                        妖狐×僕SS
# 1                My Bride is a Mermaid                         瀬戸の花嫁
# 2                   Shugo Chara!! Doki                   しゅごキャラ！！どきっ
# 3                        Princess Tutu                     プリンセスチュチュ
# ...

# %%
imageuri = []
for idx in range(len(df)):
    try:
        anime_dictionary = {
            "anime_id": df.at[idx, "anime_id"],
            "title" : df.at[idx, "title"],
            "image_url": df.at[idx, "image_url"]
        }
        imageuri.append(anime_dictionary)
        imageuri[-1]["image_url"] = imageuri[-1]["image_url"].replace("cdn-dena.com", "net")
        print('{}. {} - {}'.format(imageuri[-1]["anime_id"], imageuri[-1]["title"], imageuri[-1]["image_url"]))
    except:
        pass
# Out:
# 11013. Inu x Boku SS - https://myanimelist.net/images/anime/12/35893.jpg
# 2104. Seto no Hanayome - https://myanimelist.net/images/anime/13/58383.jpg
# 5262. Shugo Chara!! Doki - https://myanimelist.net/images/anime/11/10645.jpg
# 721. Princess Tutu - https://myanimelist.net/images/anime/13/32209.jpg
# 12365. Bakuman. 3rd Season - https://myanimelist.net/images/anime/6/41845.jpg
# 6586. Yume-iro Pâtissière - https://myanimelist.net/images/anime/12/21674.jpg
# 178. Ultra Maniac - https://myanimelist.net/images/anime/8/53571.jpg
# 2787. Shakugan no Shana II (Second) - https://myanimelist.net/images/anime/10/18669.jpg
# 4477. Nodame Cantabile: Paris-hen - https://myanimelist.net/images/anime/4/11918.jpg
# 853. Ouran Koukou Host Club - https://myanimelist.net/images/anime/2/71992.jpg
# 4814. Junjou Romantica 2 - https://myanimelist.net/images/anime/6/38417.jpg
# 7054. Kaichou wa Maid-sama! - https://myanimelist.net/images/anime/6/25254.jpg
# ...

# %%
image_base_file = "image_file"
image_format = ".jpg"
progress = 1
step = len(imageuri)//125
for item in imageuri:
    image = requests.get(item["image_url"])
    path = "%s/%s%s" % (image_base_file, item["anime_id"], image_format)
    with open(path, "wb") as file:
        file.write(image.content)
    if count % step == 0:
        print('/', end='')
    count = count + 1
# Out:
# /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %%
genrelist = []
genre = df[df["genre"].notna()]
for idx in range(len(genre)):
    try:
        genrelist.append(genre.at[idx, "genre"])
    except:
        pass

# %%
for item in genrelist:
    try:
        if item.isnan():
            
    except:
        pass

# %%
school = 0
fantasy = 0
both = 0
supernatural = 0
other = 0
for item in genrelist:
    if 'School' in item and 'Fantasy' in item:
        both = both + 1
    elif 'School' in item:
        school = school + 1
    elif 'Fantasy' in item:
        fantasy = fantasy + 1
    
    if 'Supernatural' in item:
        supernatural = supernatural + 1
    else:
        other = other + 1
print("School: ", school)
print("Fantasy: ", fantasy)
print("Both: ", both)
print("supernatural: ", supernatural)
print("Other: ", other)
# Out:
# School:  1278
# Fantasy:  2549
# Both:  125
# supernatural:  744
# Other:  9482
